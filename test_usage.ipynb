# %%
import gzip
import json
import os
import time
import networkx as nx
import math

data_folder =  'May 23 Data/data/'

# %%
# comments are AI generated, i cba

def load_data(file_path, chatter_thresholds):
    """
    Loads data from a JSON file.

    Args:
        file_path (str): Path to the JSON file.
        chatter_thresholds (int): The chatter threshold.

    Returns:
        dict: The loaded data.
    """
    st = time.time()
    print(f"opening {file_path} with {chatter_thresholds}")
    with gzip.open(file_path, 'rt') as gz_file:
        data = json.load(gz_file)
    et = time.time()
    print(f"data loaded in {(et-st):.2f}s", end="")
    return data

def add_nodes_to_graph(G, data):
    """
    Adds nodes and edges to the graph based on the input data.

    Args:
        G (networkx.Graph): The graph to which nodes and edges will be added.
        data (dict): A dictionary containing user connections.

    Returns:
        networkx.Graph: The updated graph.
    """
    st = time.time()
    count, progress = 0, 1
    print(f"\n00% - adding nodes to graph", end="")
    datalen = len(data)
    for user, connections in data.items():
        count +=1
        G.add_node(user)
        for connection in connections:
            G.add_edge(user, connection)
        if count%(datalen//100) == 0:
            print(f"\r{str(progress).zfill(2)}", end="")
            progress += 1
    et = time.time()
    print(f"\rGraph has added {G.number_of_edges()} edges between {G.number_of_nodes()} nodes in {(et-st):.2f}s\nStarting work... ", end="")
    
    return G

def calculate_thresholds(G, min_degree_threshold):
    """
    Calculates streamer thresholds based on minimum degree.

    Args:
        G (networkx.Graph): The graph containing streamer connections.
        min_degree_threshold (int): The minimum degree required.

    Returns:
        list: List of streamers that meet the degree threshold.
    """
    st = time.time()
    print(f"\n\t00% - Calculating degrees", end="")
    count, progress = 0, 1
    threshold_streamers = []
    numnodes = G.number_of_nodes() # optimized, doesnt calculate every time
    for node, degree in G.degree():
        count += 1
        if degree > min_degree_threshold:
            threshold_streamers.append(node)
        if count%(numnodes//10) == 0:
            print(f"\r\t{str(progress).zfill(2)}", end="")
            progress += 1
    et = time.time()
    print(f"\r\tCalculated degrees in {(et-st):.2f}s{' ' * 10}", end="")
    return threshold_streamers

def calculate_overlap(threshold_streamers, G): # redundant
    """
    Calculates overlap of viewers between streamers.
    Kept for documentation purposes

    Args:
        threshold_streamers (list): List of streamers to analyze.
        G (networkx.Graph): The graph containing streamer connections.

    Returns:
        dict: A dictionary of common viewers between streamers.
    """
    st = time.time()
    common_viewers_dict = {}
    # print(f"\n\tThere are {len(threshold_streamers)} selected", end="")
    print()
    for i, node_i in enumerate(threshold_streamers[:-1]):
        progress = 1
        print(f"\r\t00% - Calculating overlap for {node_i}, streamer {i} out of {len(threshold_streamers)}{' ' * 100}", end="")
        
        numstreamers = len(threshold_streamers[i+1:])
        iset = set(G.neighbors(node_i)) # optimized, no need to calculate in j
        
        for j, node_j in enumerate(threshold_streamers[i+1:]):
            if j%((numstreamers//100) + 1) == 0:
                progress += 1
                print(f"\r\t{str(progress).zfill(2)}", end="")
            common_neighbors = iset & set(G.neighbors(node_j))
            common_viewers_dict[(node_i, node_j)] = common_neighbors
        # I FIGURED OUT PROGRESS INDICATORS !!!!
        # AND ALSO SUB INDICATORS !!
    et = time.time()
    print(f"\r\tCalculated overlap in {(et-st):.2f}s{' ' * 100}", end="")
    
    return common_viewers_dict

def construct_weighted(weighted_graph, G, common_viewers_dict): # redundant
    """
    Constructs a weighted graph based on common viewers between streamers.
    Kept for documentation purposes

    Args:
        weighted_graph (networkx.Graph): The graph to which weighted edges will be added.
        G (networkx.Graph): The original graph containing streamer connections.
        common_viewers_dict (dict): A dictionary of common viewers between streamers.

    Returns:
        networkx.Graph: The weighted graph.
    """
    st = time.time()
    print()
    print(f"\r\t00% - Generating weighted graph", end="")
    count, progress = 0, 1
    numnodespcnt = len(common_viewers_dict) // 100 # optimized to not be calcs in if statement
    for pair, viewers in common_viewers_dict.items():
        count+=1
        if count%numnodespcnt == 0:
            progress += 1
            print(f"\r\t{str(progress).zfill(2)}", end="")
        node1, node2 = pair
        weighted_graph.add_edge(node1, node2, weight=len(viewers))
        weighted_graph.nodes[node1]['viewer_count'] = len(set(G.neighbors(node1)))
        weighted_graph.nodes[node2]['viewer_count'] = len(set(G.neighbors(node2)))
    et = time.time()
    print(f"\r\tGenerated weighted graph in {(et-st):.2f}s{' ' * 100}", end="")
    
    return weighted_graph

def calc_overlap_and_weighted(threshold_streamers, G, weighted_graph, edge_weight_threshold):
    """
    Calculates overlap of viewers and constructs a weighted graph based on common viewers between streamers with a combined function.

    Args:
        threshold_streamers (list): List of streamers to analyze.
        G (networkx.Graph): The graph containing streamer connections.
        weighted_graph (networkx.Graph): The graph to which weighted edges will be added.
        edge_weight_threshold (float): The threshold for edge weights (0 < edge_weight_threshold < 1).

    Returns:
        networkx.Graph or int: 
            - If edge_weight_threshold is not within (0, 1), returns -1 and prints an error message.
            - Otherwise, returns the weighted graph with added edges based on common viewers.

    Note:
        This function calculates the overlap of viewers between streamers and adds weighted edges to the weighted_graph
        based on the common viewers. It also sets the 'viewer_count' attribute for each node in the weighted graph.
        The edge_weight_threshold controls which common viewers are considered when adding edges.
        Almost twice as fast as doing both separately, AFTER both were optimized from 10min to 3min
    """
    if (edge_weight_threshold >= 1) or (edge_weight_threshold <= 0):
        print(f"edge weight threshold of {edge_weight_threshold} not allowed. It is a fraction, please keep within 0 to 1")
        return -1
    st = time.time()
    print()
    for i, node_i in enumerate(threshold_streamers[:-1]):
        progress = 1
        print(f"\r\t00% - Calculating overlap/weights for {node_i}, streamer {i} out of {len(threshold_streamers)}{' ' * 100}", end="")
        
        numstreamers = len(threshold_streamers[i+1:])
        iset = set(G.neighbors(node_i))
        
        for j, node_j in enumerate(threshold_streamers[i+1:]):
            if j%((numstreamers//100) + 1) == 0:
                progress += 1
                print(f"\r\t{str(progress).zfill(2)}", end="")
            jset = set(G.neighbors(node_j))
            common_neighbors = len(iset & jset)
            if common_neighbors > min(len(iset), len(jset))*(edge_weight_threshold):
                weighted_graph.add_edge(node_i, node_j, weight=common_neighbors)
                weighted_graph.nodes[node_i]['viewer_count'] = len(iset)
                weighted_graph.nodes[node_j]['viewer_count'] = len(jset)
    et = time.time()
    print(f"\r\tCalculated overlap and weight in {(et-st):.2f}s{' ' * 100}", end="")        
    
    return weighted_graph

# %%
def convert_to_gml(data_folder, file_name, chatter_thresholds, edge_weight_threshold, savefolder):
    """
    Edit: renamed to 'convert_to_gml' from 'analyze_file'
    Analyzes a file and creates weighted graphs for different chatter thresholds.

    Args:
        file_path (str): Path to the JSON file.
        chatter_thresholds (list): List of chatter thresholds to analyze.

    Returns:
        int: 0 if successful, -1 if there was an error.
    """
    file_path = f"{data_folder}/{file_name}"
    data = load_data(file_path, chatter_thresholds)
    # i need to add error handling for returns
    G = nx.Graph()
    G = add_nodes_to_graph(G, data)
    
    for chatter_length in chatter_thresholds:
        st = time.time()
        print(f"\nmaking graph for {chatter_length}", end="")
        min_degree_threshold = chatter_length
        
        threshold_streamers = calculate_thresholds(G, min_degree_threshold)
        
        weighted_graph = nx.Graph()
        weighted_graph = calc_overlap_and_weighted(threshold_streamers, G, weighted_graph, edge_weight_threshold)
            
        print(f"\n\tgraph for streamer threshold {chatter_length} has {weighted_graph.number_of_edges()} edges between {weighted_graph.number_of_nodes()} nodes")
        save_path = os.path.join(f"{savefolder}/{file_name.replace('.json.gz', '')}_{chatter_length}_{edge_weight_threshold}.gml")
        # os.makedirs(f"weighted_graphs/{file_path}", exist_ok=True)
        nx.write_gml(weighted_graph, save_path)

        et = time.time()
        print(f"\nTime taken for {chatter_length} is {(et-st):.2f}s")
    
    return 0

# %%
def is_corrupted(filename):
    corrupted_dates = ["2023-03-03", "2023-03-11", "2023-03-14", "2023-03-29"]
    
    # Extract the date part from the filename
    date_part = filename.split('.')[0]
    
    # Check if the date is in the list of corrupted dates
    return date_part in corrupted_dates

# %%
# do i need a separeate calc weighted graph func? cant i just do it in the cal overlap?
# do this later 
edge_weight_threshold = 0.1
chatter_thresholds = [2500]#10000, 5000, 1000]
# mega_graph = nx.Graph()
savefolder = 'fullgraph'
for filename in os.listdir(data_folder):
    if is_corrupted(filename):
        print(f"Skipping {filename} because it's a corrupted date.")
        continue  # Skip this file
    retval = convert_to_gml(data_folder, filename, chatter_thresholds, edge_weight_threshold, savefolder)
    
    # date = filename.replace('.json.gz', '')
    # subgraph = nx.read_gml(f"{savefolder}/{date}_{chatter_thresholds[0]}_{edge_weight_threshold}.gml")
    
    # nx.set_node_attributes()
    
    # mega_graph.add_nodes_from(subgraph.nodes(data=True))
    
    print(f"returned with value {retval}")
# Out:
# opening May 23 Data/data//2023-03-01.json.gz with [2500]
# data loaded in 13.43s
# Graph has added 12468275 edges between 7695662 nodes in 31.43s
# Starting work...
# making graph for 2500
# 	Calculated degrees in 3.78s
# 	Calculated overlap and weight in 606.80s
# 	graph for streamer threshold 2500 has 1839 edges between 790 nodes
#
# Time taken for 2500 is 610.59s
# returned with value 0
# opening May 23 Data/data//2023-03-02.json.gz with [2500]
# data loaded in 25.90s
# Graph has added 13662764 edges between 8143077 nodes in 34.16s
# Starting work...
# making graph for 2500
# 	Calculated degrees in 4.39s
# 	Calculated overlap and weight in 795.64s
# 	graph for streamer threshold 2500 has 2211 edges between 888 nodes
#
# Time taken for 2500 is 800.04s
# returned with value 0
# Skipping 2023-03-03.json.gz because it's a corrupted date.
# opening May 23 Data/data//2023-03-04.json.gz with [2500]
# data loaded in 27.22s
# Graph has added 13220213 edges between 7892600 nodes in 36.78s
# Starting work...
# making graph for 2500
# 	Calculated degrees in 4.90s
# 	Calculated overlap and weight in 794.14s
# 	graph for streamer threshold 2500 has 2099 edges between 860 nodes
#
# Time taken for 2500 is 799.05s
# returned with value 0
# opening May 23 Data/data//2023-03-05.json.gz with [2500]
# data loaded in 24.62s
# Graph has added 12851859 edges between 7725894 nodes in 36.00s
# Starting work...
# making graph for 2500
# 	Calculated degrees in 4.29s
# 	Calculated overlap and weight in 709.93s
# 	graph for streamer threshold 2500 has 2061 edges between 825 nodes
#
# Time taken for 2500 is 714.23s
# returned with value 0
# opening May 23 Data/data//2023-03-06.json.gz with [2500]
# data loaded in 22.69s
# Graph has added 10723781 edges between 6619757 nodes in 31.43s
# Starting work...
# making graph for 2500
# 	Calculated degrees in 3.67s
# 	Calculated overlap and weight in 535.04s
# 	graph for streamer threshold 2500 has 1778 edges between 851 nodes
#
# Time taken for 2500 is 538.73s
# returned with value 0
# opening May 23 Data/data//2023-03-07.json.gz with [2500]
# data loaded in 23.54s
# Graph has added 10570453 edges between 6530467 nodes in 35.22s
# Starting work...
# making graph for 2500
# 	Calculated degrees in 3.65s
# 	Calculated overlap and weight in 561.21s
# 	graph for streamer threshold 2500 has 1695 edges between 819 nodes
#
# Time taken for 2500 is 564.87s
# returned with value 0
# opening May 23 Data/data//2023-03-08.json.gz with [2500]
# data loaded in 20.91s
# Graph has added 10614261 edges between 6640058 nodes in 31.30s
# Starting work...
# making graph for 2500
# 	Calculated degrees in 3.68s
# 	Calculated overlap and weight in 453.95s
# 	graph for streamer threshold 2500 has 1672 edges between 796 nodes
#
# Time taken for 2500 is 457.64s
# returned with value 0
# opening May 23 Data/data//2023-03-09.json.gz with [2500]
# data loaded in 22.51s
# Graph has added 10703633 edges between 6682716 nodes in 31.14s
# Starting work...
# making graph for 2500
# 	Calculated degrees in 3.72s
# 	Calculated overlap and weight in 458.56s
# 	graph for streamer threshold 2500 has 1637 edges between 815 nodes
#
# Time taken for 2500 is 462.30s
# returned with value 0
# opening May 23 Data/data//2023-03-10.json.gz with [2500]
# data loaded in 26.65s
# Graph has added 11377991 edges between 7093041 nodes in 32.43s
# Starting work...
# making graph for 2500
# 	Calculated degrees in 3.98s
# 	Calculated overlap and weight in 584.32s
# 	graph for streamer threshold 2500 has 1718 edges between 803 nodes
#
# Time taken for 2500 is 588.31s
# returned with value 0
# Skipping 2023-03-11.json.gz because it's a corrupted date.
# opening May 23 Data/data//2023-03-12.json.gz with [2500]
# data loaded in 29.92s
# Graph has added 12553884 edges between 7586140 nodes in 35.38s
# Starting work...
# making graph for 2500
# 	Calculated degrees in 4.26s
# 	Calculated overlap and weight in 650.05s
# 	graph for streamer threshold 2500 has 1928 edges between 829 nodes
#
# Time taken for 2500 is 654.32s
# returned with value 0
# opening May 23 Data/data//2023-03-13.json.gz with [2500]
# data loaded in 21.38s
# Graph has added 10884320 edges between 6794357 nodes in 31.81s
# Starting work...
# making graph for 2500
# 	Calculated degrees in 3.76s
# 	Calculated overlap and weight in 503.88s
# 	graph for streamer threshold 2500 has 1667 edges between 807 nodes
#
# Time taken for 2500 is 507.64s
# returned with value 0
# Skipping 2023-03-14.json.gz because it's a corrupted date.
# opening May 23 Data/data//2023-03-15.json.gz with [2500]
# data loaded in 24.33s
# Graph has added 10615405 edges between 6591020 nodes in 31.44s
# Starting work...
# making graph for 2500
# 	Calculated degrees in 3.68s
# 	Calculated overlap and weight in 495.15s
# 	graph for streamer threshold 2500 has 1606 edges between 760 nodes
#
# Time taken for 2500 is 498.84s
# returned with value 0
# opening May 23 Data/data//2023-03-16.json.gz with [2500]
# data loaded in 22.06s
# Graph has added 10698291 edges between 6638619 nodes in 30.09s
# Starting work...
# making graph for 2500
# 	Calculated degrees in 3.74s
# 	Calculated overlap and weight in 464.74s
# 	graph for streamer threshold 2500 has 1653 edges between 782 nodes
#
# Time taken for 2500 is 468.50s
# returned with value 0
# opening May 23 Data/data//2023-03-17.json.gz with [2500]
# data loaded in 21.52s
# Graph has added 11086943 edges between 6813301 nodes in 24.32s
# Starting work...
# making graph for 2500
# 	Calculated degrees in 3.27s
# 	Calculated overlap and weight in 477.89s
# 	graph for streamer threshold 2500 has 1852 edges between 822 nodes
#
# Time taken for 2500 is 481.17s
# returned with value 0
# opening May 23 Data/data//2023-03-18.json.gz with [2500]
# data loaded in 21.82s
# Graph has added 11827443 edges between 6990140 nodes in 29.61s
# Starting work...
# making graph for 2500
# 	Calculated degrees in 3.71s
# 	Calculated overlap and weight in 610.22s
# 	graph for streamer threshold 2500 has 2025 edges between 866 nodes
#
# Time taken for 2500 is 613.94s
# returned with value 0
# opening May 23 Data/data//2023-03-19.json.gz with [2500]
# data loaded in 24.46s
# Graph has added 12468536 edges between 7425380 nodes in 30.47s
# Starting work...
# making graph for 2500
# 	Calculated degrees in 3.96s
# 	Calculated overlap and weight in 645.87s
# 	graph for streamer threshold 2500 has 2215 edges between 900 nodes
#
# Time taken for 2500 is 649.85s
# returned with value 0
# opening May 23 Data/data//2023-03-20.json.gz with [2500]
# data loaded in 21.03s
# Graph has added 10797538 edges between 6679498 nodes in 24.32s
# Starting work...
# making graph for 2500
# 	Calculated degrees in 3.27s
# 	Calculated overlap and weight in 523.62s
# 	graph for streamer threshold 2500 has 1840 edges between 836 nodes
#
# Time taken for 2500 is 526.90s
# returned with value 0
# opening May 23 Data/data//2023-03-21.json.gz with [2500]
# data loaded in 20.69s
# Graph has added 11316584 edges between 6860128 nodes in 29.15s
# Starting work...
# making graph for 2500
# 	Calculated degrees in 3.63s
# 	Calculated overlap and weight in 571.28s
# 	graph for streamer threshold 2500 has 2034 edges between 883 nodes
#
# Time taken for 2500 is 574.92s
# returned with value 0
# opening May 23 Data/data//2023-03-22.json.gz with [2500]
# data loaded in 27.53s
# Graph has added 13112098 edges between 7771589 nodes in 33.25s
# Starting work...
# making graph for 2500
# 	Calculated degrees in 4.15s
# 	Calculated overlap and weight in 683.65s
# 	graph for streamer threshold 2500 has 2159 edges between 910 nodes
#
# Time taken for 2500 is 687.82s
# returned with value 0
# opening May 23 Data/data//2023-03-23.json.gz with [2500]
# data loaded in 19.51s
# Graph has added 10422969 edges between 6539893 nodes in 30.29s
# Starting work...
# making graph for 2500
# 	Calculated degrees in 3.52s
# 	Calculated overlap and weight in 402.90s
# 	graph for streamer threshold 2500 has 1605 edges between 740 nodes
#
# Time taken for 2500 is 406.43s
# returned with value 0
# opening May 23 Data/data//2023-03-24.json.gz with [2500]
# data loaded in 21.72s
# Graph has added 11843104 edges between 7253933 nodes in 37.14s
# Starting work...
# making graph for 2500
# 	Calculated degrees in 3.99s
# 	Calculated overlap and weight in 493.07s
# 	graph for streamer threshold 2500 has 1756 edges between 800 nodes
#
# Time taken for 2500 is 497.07s
# returned with value 0
# opening May 23 Data/data//2023-03-25.json.gz with [2500]
# data loaded in 18.50s
# Graph has added 11495221 edges between 6865838 nodes in 31.17s
# Starting work...
# making graph for 2500
# 	Calculated degrees in 3.80s
# 	Calculated overlap and weight in 483.26s
# 	graph for streamer threshold 2500 has 1835 edges between 821 nodes
#
# Time taken for 2500 is 487.07s
# returned with value 0
# opening May 23 Data/data//2023-03-26.json.gz with [2500]
# data loaded in 28.79s
# Graph has added 13285429 edges between 7891728 nodes in 32.61s
# Starting work...
# making graph for 2500
# 	Calculated degrees in 4.25s
# 	Calculated overlap and weight in 662.24s
# 	graph for streamer threshold 2500 has 2167 edges between 902 nodes
#
# Time taken for 2500 is 666.50s
# returned with value 0
# opening May 23 Data/data//2023-03-27.json.gz with [2500]
# data loaded in 22.61s
# Graph has added 11309578 edges between 6880327 nodes in 31.36s
# Starting work...
# making graph for 2500
# 	Calculated degrees in 3.76s
# 	Calculated overlap and weight in 533.10s
# 	graph for streamer threshold 2500 has 1879 edges between 837 nodes
#
# Time taken for 2500 is 536.87s
# returned with value 0
# opening May 23 Data/data//2023-03-28.json.gz with [2500]
# data loaded in 20.10s
# Graph has added 8220676 edges between 5345875 nodes in 24.78s
# Starting work...
# making graph for 2500
# 	Calculated degrees in 3.10s
# 	Calculated overlap and weight in 303.77s
# 	graph for streamer threshold 2500 has 1226 edges between 632 nodes
#
# Time taken for 2500 is 306.88s
# returned with value 0
# Skipping 2023-03-29.json.gz because it's a corrupted date.
# opening May 23 Data/data//2023-03-30.json.gz with [2500]
# data loaded in 16.64s
# Graph has added 7271621 edges between 4839978 nodes in 21.76s
# Starting work...
# making graph for 2500
# 	Calculated degrees in 2.82s
# 	Calculated overlap and weight in 261.93s
# 	graph for streamer threshold 2500 has 995 edges between 543 nodes
#
# Time taken for 2500 is 264.75s
# returned with value 0
# opening May 23 Data/data//2023-03-31.json.gz with [2500]
# data loaded in 14.66s
# Graph has added 5433856 edges between 4010413 nodes in 14.28s
# Starting work...
# making graph for 2500
# 	Calculated degrees in 2.02s
# 	Calculated overlap and weight in 94.33s
# 	graph for streamer threshold 2500 has 484 edges between 345 nodes
#
# Time taken for 2500 is 96.36s
# returned with value 0

# %%
# for filename in os.listdir(data_folder):
#     # print(filename)
#     #<give code to skip the file if its one of the below dates. the file name format is "2023-03-<day of the month>.json.gz">
#     if is_corrupted(filename):
#         print(f"Skipping {filename} because it's a corrupted date.")
#         continue  # Skip this file
#     file_path = os.path.join(data_folder, filename)
#     if filename.endswith('01.json.gz'):
#         analyze_file(file_path)
        
# # preliminary check, files for 3rd, 11th, 14th, and 29th are corrupted (EOF Error). 
# # Will check if its a download issue or upload issue
